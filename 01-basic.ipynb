# %%
1+1
# Out:
# 2

# %%
import os, re
re.search("^(cpu|gpu)(-big)?$",os.environ["AZNB_IMAGE_TYPE"]) != None
# Out:
# True

# %%
re.search("^(pr-)?[0-9a-f]{7,10}-20[0-9]{10}$",os.environ["AZNB_IMAGE_VERSION"]) != None
# Out:
# True
